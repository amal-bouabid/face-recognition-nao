# %%
print(f"Nombre d'images dans train_generator: {train_generator.samples}")
print(f"Nombre d'images dans val_generator: {val_generator.samples}")
print(f"Nombre d'images dans val_generator: {test_generator.samples}")
# Out:
# Nombre d'images dans train_generator: 3623
# Nombre d'images dans val_generator: 760
# Nombre d'images dans val_generator: 811
